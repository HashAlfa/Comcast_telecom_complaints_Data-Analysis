# %% [markdown]
# ###  Project on Data Analysis

# %% [markdown]
# Objective :
#
# 1. Explorative Data Analysis
# 2. Data Cleaning
# 3. Data Pre processing
# 4. Data Visualization
#
# Libraries :
#
# 1. pandas : manipulating data
# 2. numpy  : algebric expessions
# 3. matplotlib/seaborn : visualization libraries

# %%
import pandas as pd
import numpy as nm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read .csv file

df = pd.read_csv("Comcast_telecom_complaints_data.csv")

# %%
# Exploratory Data Analysis :

# shape
# head()
# tail()
# sample()

# %%
df
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-15
# 1      223441       Payment disappear - service got disconnected  04-08-15
# 2      242732                                  Speed and Service  18-04-15
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4      307175         Comcast not working and no service to boot  26-05-15
# ...       ...                                                ...       ...
# 2219   213550                               Service Availability  04-02-15
# 2220   318775         Comcast Monthly Billing for Returned Modem  06-02-15
# 2221   331188                            complaint about comcast  06-09-15
# 2222   360489             Extremely unsatisfied Comcast customer  23-06-15
# 2223   363614               Comcast, Ypsilanti MI Internet Speed  24-06-15
#
# ...

# %%
# returns total no of rows, columns

df.shape
# Out:
# (2224, 11)

# %%
# head() : returns first 5 rows 

df.head(10)
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
# 5   338519  ISP Charging for arbitrary data limits with ov...  06-12-15
# 6   361148      Throttling service and unreasonable data caps  24-06-15
# 7   359792  Comcast refuses to help troubleshoot and corre...  23-06-15
# 8   318072                           Comcast extended outages  06-01-15
# 9   371214  Comcast Raising Prices and Not Being Available...  28-06-15
#
#   Date_month_year         Time        Received Via      City       State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon    Maryland
# ...

# %%
# tail() : returns last 5 rows

df.tail(10)
# Out:
#      Ticket #                               Customer Complaint      Date  \
# 2214   310847                 Comcast Internet Service quality  28-05-15
# 2215   360946                           Comcast unfair pricing  24-06-15
# 2216   363852                       High Internet & Cable Bill  25-06-15
# 2217   254488                   problems with internet service  24-04-15
# 2218   338192  Speed throttling, speeds not at promised output  06-12-15
# 2219   213550                             Service Availability  04-02-15
# 2220   318775       Comcast Monthly Billing for Returned Modem  06-02-15
# 2221   331188                          complaint about comcast  06-09-15
# 2222   360489           Extremely unsatisfied Comcast customer  23-06-15
# 2223   363614             Comcast, Ypsilanti MI Internet Speed  24-06-15
#
#      Date_month_year         Time        Received Via        City  \
# 2214       28-May-15   8:56:14 AM            Internet        York
# ...

# %%
# sample() : returns random row

df.sample(5)
# Out:
#      Ticket #                              Customer Complaint      Date  \
# 1568   360394  Comcast's Unfair Billing and Pricing Practices  23-06-15
# 666    364369                                   BILLING ISSUE  25-06-15
# 969    338785                        Complaints about comcast  13-06-15
# 2069   360493                     Comcast service and billing  23-06-15
# 1653   245893                   internet pricing /competition  20-04-15
#
#      Date_month_year         Time        Received Via          City  \
# 1568       23-Jun-15  10:44:41 PM  Customer Care Call    Pittsburgh
# 666        25-Jun-15  11:48:15 AM            Internet        Eustis
# 969        13-Jun-15   9:55:58 AM  Customer Care Call  Jacksonville
# 2069       23-Jun-15  11:14:43 PM            Internet        Tucson
# 1653       20-Apr-15   7:37:28 PM  Customer Care Call        Ramsey
#
#              State  Zip code   Status Filing on Behalf of Someone
# ...

# %%
# info() : to check datatypes :

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   object
#  3   Date_month_year              2224 non-null   object
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 191.2+ KB

# %%
# isnull() : to check null values 

df.isnull().sum()
# Out:
# Ticket #                       0
# Customer Complaint             0
# Date                           0
# Date_month_year                0
# Time                           0
# Received Via                   0
# City                           0
# State                          0
# Zip code                       0
# Status                         0
# Filing on Behalf of Someone    0
# dtype: int64

# %%
# unique() : return unique values in column.

df['Received Via'].unique()
# Out:
# array(['Customer Care Call', 'Internet'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Abingdon', 'Acworth', 'Adrian', 'Alameda', 'Albuquerque',
#        'Albuquerqur', 'Alexandria', 'Algonquin', 'Aliquippa', 'Allston',
#        'Aloha', 'Alpharetta', 'Alvin', 'Ambridge', 'Amesbury', 'Amherst',
#        'Andover', 'Angels Camp', 'Ann Arbor', 'Annapolis', 'Annville',
#        'Anoka', 'Antioch', 'Aptos', 'Arlington', 'Arlington Heights',
#        'Arvada', 'Ashland', 'Athens', 'Atlanta', 'Atlantic Beach',
#        'Attalla', 'Attica', 'Auburn', 'Augusta', 'Aurora', 'Austell',
#        'Austin', 'Avon', 'Ayer', 'Baden', 'Bainbridge Island',
#        'Bala Cynwyd', 'Ballston Lake', 'Baltimore', 'Bargersville',
#        'Barnegat', 'Barrington', 'Bartlett', 'Bartonville', 'Bath',
#        'Battle Ground', 'Beach Haven', 'Beachwood', 'Beale Afb',
#        'Beaver Falls', 'Beaverton', 'Bedford', 'Bel Air', 'Belleville',
#        'Bellevue', 'Bellingham', 'Belmont', 'Belton', 'Beltsville',
#        'Belvidere', 'Bensalem', 'Berkeley', 'Berkeley Lake',
# ...

# %%
df['Status'].unique()
# Out:
# array(['Closed', 'Open', 'Solved', 'Pending'], dtype=object)

# %%
df['Filing on Behalf of Someone'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# describe() : rerurns various statistical features

df.describe()
# Out:
#            Zip code
# count   2224.000000
# mean   47994.393435
# std    28885.279427
# min     1075.000000
# 25%    30056.500000
# 50%    37211.000000
# 75%    77058.750000
# max    99223.000000

# %%
1,3,4,2,5 ,1,1

mean = 1+3+4+2+5+1+1 = 17/7 = 2.7
median = 1,1,1,2,3,4,5      = 2
mode = 1
range : 5 - 1 = 4
    
1,1  | 1,2 | 3,4 |  5
    Q1     Q2   Q3 
    1      2.5  4.5

# %%
# missing values : 

# 1. remove/delete rows
# 2. replace => mean, median, mode

# %%
Data  :  
    
    1. Past and Present Instances : => Data Analytics
    2. Future Instances             => Statistical Tool => Machine Learning =>  Regression / Classification ...

# %%
X   10     20     30    40     45    50

Y   20     40     60

# %%
Y  =  m * X  + C

m = 2
c = 0

Y =  2 * X

# %%
# Data Preprocessing :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   object
#  3   Date_month_year              2224 non-null   object
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 191.2+ KB

# %%
# convert datatype of  'Date_month_year' to 'datetime'

df['Date_month_year'] =  df['Date_month_year'].apply(pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   object
#  3   Date_month_year              2224 non-null   datetime64[ns]
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 191.2+ KB

# %%
# convert 'Zip code' into object

df['Zip code'] = df['Zip code'].astype(object)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   object
#  3   Date_month_year              2224 non-null   datetime64[ns]
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   object
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 191.2+ KB

# %%
df['Status'].unique()
# Out:
# array(['Closed', 'Open', 'Solved', 'Pending'], dtype=object)

# %%
# Data Bucketing : 

# List Comprehension

# list_name = [var        if condition else        for i in sequence_name ]

df['new_Status'] = ['Closed'   if i == 'Closed' or i=='Solved'  else  'Open'       for i in df['Status'] ]

# %%
df.head(10)
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
# 5   338519  ISP Charging for arbitrary data limits with ov...  06-12-15
# 6   361148      Throttling service and unreasonable data caps  24-06-15
# 7   359792  Comcast refuses to help troubleshoot and corre...  23-06-15
# 8   318072                           Comcast extended outages  06-01-15
# 9   371214  Comcast Raising Prices and Not Being Available...  28-06-15
#
#   Date_month_year         Time        Received Via      City       State  \
# 0      2015-04-22   3:53:50 PM  Customer Care Call  Abingdon    Maryland
# ...

# %%
df['new_Status'].unique()
# Out:
# array(['Closed', 'Open'], dtype=object)

# %%
# Data Analysis using data Visualization : 

# 1. Univariate Analysis :

# %%
# 1. How many daily complaints received ?

df['Date_month_year'].value_counts()[: 5]
# Out:
# 2015-06-24    218
# 2015-06-23    190
# 2015-06-25     98
# 2015-06-26     55
# 2015-06-30     53
# Name: Date_month_year, dtype: int64

# %%
df['Date_month_year'].value_counts()[: 10].plot()

plt.title('Daily Compliant Chart')
plt.xlabel('Dates')
plt.ylabel(' No of Complaints Received ')
plt.show()

# %%
# Give top 10 states with complaints?

df['State'].value_counts()[: 10]
# Out:
# Georgia         288
# Florida         240
# California      220
# Illinois        164
# Tennessee       143
# Pennsylvania    130
# Michigan        115
# Washington       98
# Colorado         80
# Maryland         78
# Name: State, dtype: int64

# %%
df['State'].value_counts()[: 10].plot.bar(figsize = (10,7))

# %%
# 2. Bivariate analysis : 

# 1. Give statewise complaint status.

# groupby()

df.groupby(['State' ,'new_Status']).size()
# Out:
# State          new_Status
# Alabama        Closed        17
#                Open           9
# Arizona        Closed        14
#                Open           6
# Arkansas       Closed         6
#                              ..
# Virginia       Open          11
# Washington     Closed        75
#                Open          23
# West Virginia  Closed         8
#                Open           3
# Length: 77, dtype: int64

# %%
# to convert into tabular format

df.groupby(['State' ,'new_Status']).size().unstack()
# Out:
# new_Status            Closed  Open
# State
# Alabama                 17.0   9.0
# Arizona                 14.0   6.0
# Arkansas                 6.0   NaN
# California             159.0  61.0
# Colorado                58.0  22.0
# Connecticut              9.0   3.0
# Delaware                 8.0   4.0
# District Of Columbia    14.0   2.0
# District of Columbia     1.0   NaN
# Florida                201.0  39.0
# Georgia                208.0  80.0
# Illinois               135.0  29.0
# Indiana                 50.0   9.0
# Iowa                     1.0   NaN
# Kansas                   1.0   1.0
# Kentucky                 4.0   3.0
# Louisiana               12.0   1.0
# Maine                    3.0   2.0
# Maryland                63.0  15.0
# Massachusetts           50.0  11.0
# Michigan                92.0  23.0
# Minnesota               29.0   4.0
# Mississippi             23.0  16.0
# Missouri                 3.0   1.0
# Montana                  1.0   NaN
# ...

# %%
# top 5 complaint receiving states.

df.groupby(['State']).size().sort_values(ascending = False)[:5]
# Out:
# State
# Georgia       288
# Florida       240
# California    220
# Illinois      164
# Tennessee     143
# dtype: int64

# %%
# Plot Statewise Complaints

statewise_complaint = df.groupby(['State' ,'new_Status']).size().unstack()[:10]

statewise_complaint.plot.bar(figsize = (15,7), stacked = True)
